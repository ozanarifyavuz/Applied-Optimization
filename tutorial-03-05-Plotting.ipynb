# %% [markdown]
# # Tutorial III.III - DataFrames in Julia
#
# Applied Optimization with Julia
#
# # Introduction
#
# Welcome to this tutorial on plotting in Julia! We’ll be using the
# powerful Plots.jl package to create beautiful and informative
# visualizations. Don’t worry if you’re new to plotting – we’ll start with
# the basics and gradually build up to more advanced techniques.
#
# In this tutorial, you’ll learn how to: 1. Create simple plots like line
# graphs and scatter plots 2. Customize your plots with colors, labels,
# and styles 3. Add multiple data series to a single plot 4. Save your
# plots as image files for use in reports or presentations
#
# Follow the instructions, write your code in the designated code blocks,
# and validate your results with `@assert` statements.
#
# Before we begin, let’s make sure you have the necessary packages
# installed. If you’ve been following the course, you’ll need to install
# the Plots and StatsPlots packages:

# %%
import Pkg
Pkg.activate("applied-optimization")
Pkg.add(["Plots","StatsPlots"])
# Out:
#   Activating project at `c:\Users\Ozan Arif Yavuz\OneDrive\Masaüstü\Applied Optimization\applied-optimization`
#     Updating registry at `C:\Users\Ozan Arif Yavuz\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed HypergeometricFunctions ────── v0.3.28
#    Installed JpegTurbo_jll ──────────────── v3.1.3+0
#    Installed Libmount_jll ───────────────── v2.41.2+0
#    Installed OffsetArrays ───────────────── v1.17.0
#    Installed GR_jll ─────────────────────── v0.73.18+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed StatsFuns ──────────────────── v1.5.2
#    Installed LoggingExtras ──────────────── v1.2.0
#    Installed FFTW ───────────────────────── v1.10.0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Opus_jll ───────────────────── v1.5.2+0
#    Installed PDMats ─────────────────────── v0.11.36
#    Installed Measures ───────────────────── v0.3.3
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Contour ────────────────────── v0.6.3
#    Installed NearestNeighbors ───────────── v0.4.22
#    Installed StaticArrays ───────────────── v1.9.15
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed PlotUtils ──────────────────── v1.4.4
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed OpenSSL ────────────────────── v1.6.0
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed HTTP ───────────────────────── v1.10.19
#    Installed Cairo_jll ──────────────────── v1.18.5+0
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Fontconfig_jll ─────────────── v2.17.1+0
#    Installed IntelOpenMP_jll ────────────── v2025.2.0+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.6+0
#    Installed FFMPEG ─────────────────────── v0.4.5
#    Installed Distances ──────────────────── v0.10.12
#    Installed Showoff ────────────────────── v1.0.3
#    Installed Pango_jll ──────────────────── v1.56.4+0
#    Installed PtrArrays ──────────────────── v1.3.0
#    Installed xkbcommon_jll ──────────────── v1.9.2+0
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed Clustering ─────────────────── v0.15.8
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed Rmath_jll ──────────────────── v0.5.1+0
#    Installed MbedTLS ────────────────────── v1.1.9
#    Installed Ratios ─────────────────────── v0.4.5
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed x264_jll ───────────────────── v10164.0.1+0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed Colors ─────────────────────── v0.13.1
#    Installed StatsAPI ───────────────────── v1.7.1
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed StatsBase ──────────────────── v0.34.7
#    Installed libpng_jll ─────────────────── v1.6.50+0
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed libaom_jll ─────────────────── v3.13.1+0
#    Installed Scratch ────────────────────── v1.3.0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed ColorTypes ─────────────────── v0.12.1
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed StatsPlots ─────────────────── v0.15.8
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed oneTBB_jll ─────────────────── v2022.0.0+1
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Xorg_libXext_jll ───────────── v1.3.7+0
#    Installed Plots ──────────────────────── v1.41.1
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.6+0
#    Installed Expat_jll ──────────────────── v2.7.3+0
#    Installed MKL_jll ────────────────────── v2025.2.0+0
#    Installed Format ─────────────────────── v1.3.7
#    Installed Libtiff_jll ────────────────── v4.7.2+0
#    Installed AbstractFFTs ───────────────── v1.5.0
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed ChainRulesCore ─────────────── v1.26.0
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed KernelDensity ──────────────── v0.6.10
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed Ghostscript_jll ────────────── v9.55.1+0
#    Installed AliasTables ────────────────── v1.1.3
#    Installed FFTW_jll ───────────────────── v3.3.11+0
#    Installed ColorSchemes ───────────────── v3.31.0
#    Installed Libuuid_jll ────────────────── v2.41.2+0
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed Widgets ────────────────────── v0.6.7
#    Installed MbedTLS_jll ────────────────── v2.28.10+0
#    Installed MultivariateStats ──────────── v0.10.3
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed Adapt ──────────────────────── v4.4.0
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed StableRNGs ─────────────────── v1.0.3
#    Installed libass_jll ─────────────────── v0.17.4+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed Rmath ──────────────────────── v0.9.0
#    Installed Arpack_jll ─────────────────── v3.5.1+1
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed Latexify ───────────────────── v0.16.10
#    Installed FFMPEG_jll ─────────────────── v8.0.0+0
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed TableOperations ────────────── v1.2.0
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed Xorg_libXfixes_jll ─────────── v6.0.2+0
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+2
#    Installed Qt6Base_jll ────────────────── v6.8.2+2
#    Installed GettextRuntime_jll ─────────── v0.22.4+0
#    Installed URIs ───────────────────────── v1.6.1
#    Installed Arpack ─────────────────────── v0.5.4
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed Glib_jll ───────────────────── v2.86.0+0
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed FillArrays ─────────────────── v1.15.0
#    Installed AxisAlgorithms ─────────────── v1.1.0
#    Installed QuadGK ─────────────────────── v2.11.2
#    Installed Xorg_libX11_jll ────────────── v1.8.12+0
#    Installed Requires ───────────────────── v1.3.1
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Observables ────────────────── v0.5.5
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed Distributions ──────────────── v0.25.122
#    Installed WoodburyMatrices ───────────── v1.0.0
#    Installed GR ─────────────────────────── v0.73.18
#    Installed Interpolations ─────────────── v0.16.2
#   Installing 44 artifacts
#    Installed artifact Ogg                   276.9 KiB
#    Installed artifact Graphite2             226.0 KiB
#    Installed artifact XZ                    2.4 MiB
#    Installed artifact libass                509.5 KiB
#    Installed artifact Xorg_xkeyboard_config 537.5 KiB
#    Installed artifact GettextRuntime        1.1 MiB
#    Installed artifact FriBidi               140.3 KiB
#    Installed artifact Vulkan_Loader         273.3 KiB
#    Installed artifact HarfBuzz              2.8 MiB
#    Installed artifact x264                  2.5 MiB
#    Installed artifact libvorbis             355.2 KiB
#    Installed artifact FreeType2             1.6 MiB
#    Installed artifact Fontconfig            2.5 MiB
#    Installed artifact libaom                7.5 MiB
#    Installed artifact Rmath                 202.0 KiB
#    Installed artifact Libiconv              2.0 MiB
#    Installed artifact Expat                 454.5 KiB
#    Installed artifact Pixman                444.2 KiB
#    Installed artifact libfdk_aac            2.9 MiB
#    Installed artifact Arpack                239.1 KiB
#    Installed artifact libpng                494.5 KiB
#    Installed artifact fzf                   3.5 MiB
#    Installed artifact JpegTurbo             1.7 MiB
#    Installed artifact FFTW                  2.4 MiB
#    Installed artifact Libffi                100.5 KiB
#    Installed artifact LZO                   242.9 KiB
#    Installed artifact LERC                  292.1 KiB
#    Installed artifact Cairo                 2.8 MiB
#    Installed artifact FFMPEG                11.8 MiB
#    Installed artifact LLVMOpenMP            1.1 MiB
#    Installed artifact Libtiff               4.0 MiB
#    Installed artifact Qt6ShaderTools        2.2 MiB
#    Installed artifact Zstd                  1.4 MiB
#    Installed artifact GLFW                  266.2 KiB
#    Installed artifact MbedTLS               6.7 MiB
#    Installed artifact LAME                  408.6 KiB
#    Installed artifact Glib                  7.5 MiB
#    Installed artifact Opus                  1.1 MiB
#    Installed artifact x265                  3.0 MiB
#    Installed artifact Pango                 1.9 MiB
#    Installed artifact Qt6Declarative        28.2 MiB
#    Installed artifact GR                    18.1 MiB
#    Installed artifact Qt6Base               24.1 MiB
#    Installed artifact Ghostscript           55.7 MiB
#     Updating `C:\Users\Ozan Arif Yavuz\OneDrive\Masaüstü\Applied Optimization\applied-optimization\Project.toml`
#   [91a5bcdd] + Plots v1.41.1
#   [f3b207a7] + StatsPlots v0.15.8
#     Updating `C:\Users\Ozan Arif Yavuz\OneDrive\Masaüstü\Applied Optimization\applied-optimization\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [79e6a3ab] + Adapt v4.4.0
#   [66dad0bd] + AliasTables v1.1.3
#   [7d9fca2a] + Arpack v0.5.4
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [d1d4a3ce] + BitFlags v0.1.9
#   [d360d2e6] + ChainRulesCore v1.26.0
#   [aaaa29a8] + Clustering v0.15.8
#   [35d6a980] + ColorSchemes v3.31.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [b4f34e82] + Distances v0.10.12
#   [31c24e10] + Distributions v0.25.122
#   [ffbed154] + DocStringExtensions v0.9.5
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.5
#   [7a1cc6ca] + FFTW v1.10.0
#   [1a297f60] + FillArrays v1.15.0
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.18
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.19
#   [34004b35] + HypergeometricFunctions v0.3.28
#   [a98d9a8b] + Interpolations v0.16.2
#   [92d709cd] + IrrationalConstants v0.2.6
#   [1019f520] + JLFzf v0.1.11
#   [5ab0869b] + KernelDensity v0.6.10
#   [23fbe1c1] + Latexify v0.16.10
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.2.0
#   [1914dd2f] + MacroTools v0.5.16
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.3
#   [6f286f6a] + MultivariateStats v0.10.3
#   [77ba4419] + NaNMath v1.1.3
#   [b8a86587] + NearestNeighbors v0.4.22
#   [510215fc] + Observables v0.5.5
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [4d8831e6] + OpenSSL v1.6.0
#   [90014a1f] + PDMats v0.11.36
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.4
#   [91a5bcdd] + Plots v1.41.1
#   [43287f4e] + PtrArrays v1.3.0
#   [1fd47b50] + QuadGK v2.11.2
#   [c84ed2f1] + Ratios v0.4.5
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.1
#   [79098fc4] + Rmath v0.9.0
#   [6c6a2e73] + Scratch v1.3.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [276daf66] + SpecialFunctions v2.6.1
#   [860ef19b] + StableRNGs v1.0.3
#   [90137ffa] + StaticArrays v1.9.15
#   [1e83bf80] + StaticArraysCore v1.4.4
#   [82ae8749] + StatsAPI v1.7.1
#   [2913bbd2] + StatsBase v0.34.7
#   [4c63d2b9] + StatsFuns v1.5.2
#   [f3b207a7] + StatsPlots v0.15.8
#   [ab02a1b2] + TableOperations v1.2.0
#   [62fd8b95] + TensorCore v0.1.1
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [41fe7b60] + Unzip v0.2.0
#   [cc8bc4a8] + Widgets v0.6.7
#   [efce3f68] + WoodburyMatrices v1.0.0
# ⌅ [68821587] + Arpack_jll v3.5.1+1
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.7.3+0
#   [b22a6f82] + FFMPEG_jll v8.0.0+0
#   [f5851436] + FFTW_jll v3.3.11+0
#   [a3f928ae] + Fontconfig_jll v2.17.1+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.18+0
#   [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [61579ee1] + Ghostscript_jll v9.55.1+0
#   [7746bdde] + Glib_jll v2.86.0+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.2.0+0
#   [aacddb02] + JpegTurbo_jll v3.1.3+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
#   [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.2+0
#   [89763e89] + Libtiff_jll v4.7.2+0
#   [38a345b3] + Libuuid_jll v2.41.2+0
#   [856f044c] + MKL_jll v2025.2.0+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.10+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
#   [91d4177d] + Opus_jll v1.5.2+0
#   [36c8627f] + Pango_jll v1.56.4+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6.8.2+2
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+2
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.12+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.7+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.2+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.6+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.6+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.13.1+0
#   [0ac62f75] + libass_jll v0.17.4+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [b53b4c65] + libpng_jll v1.6.50+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+1
#   [1270edf5] + x264_jll v10164.0.1+0
#   [dfaa095f] + x265_jll v4.1.0+0
#   [d8fb68d0] + xkbcommon_jll v1.9.2+0
#   [8ba89e20] + Distributed v1.11.0
#   [4af54fe1] + LazyArtifacts v1.11.0
#   [9e88b42a] + Serialization v1.11.0
#   [1a1011a3] + SharedArrays v1.11.0
#   [2f01184e] + SparseArrays v1.12.0
#   [4607b0f0] + SuiteSparse
#   [8dfed614] + Test v1.11.0
#   [05823500] + OpenLibm_jll v0.8.7+0
#   [efcefdf7] + PCRE2_jll v10.44.0+1
#   [bea87d4a] + SuiteSparse_jll v7.8.3+2
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling packages...
#    5976.8 ms  ✓ AbstractFFTs
#    3402.0 ms  ✓ TensorCore
#    3390.3 ms  ✓ StatsAPI
#    5940.5 ms  ✓ Contour
#    5928.1 ms  ✓ OffsetArrays
#    1642.9 ms  ✓ Measures
#    1947.1 ms  ✓ Observables
#    3318.0 ms  ✓ Grisu
#    3336.8 ms  ✓ FillArrays
#    1584.9 ms  ✓ StableRNGs
#    2500.3 ms  ✓ Requires
#    4867.3 ms  ✓ Format
#    1400.9 ms  ✓ SimpleBufferStream
#    1970.7 ms  ✓ Unzip
#    2155.5 ms  ✓ URIs
#    1384.7 ms  ✓ PtrArrays
#    1360.9 ms  ✓ BitFlags
#    1586.1 ms  ✓ DelimitedFiles
#    2894.4 ms  ✓ SuiteSparse
#    2887.5 ms  ✓ ConcurrentUtilities
#    2137.8 ms  ✓ WoodburyMatrices
#    1448.8 ms  ✓ Scratch
#    3567.5 ms  ✓ QuadGK
#    1832.6 ms  ✓ LoggingExtras
#    2122.8 ms  ✓ ExceptionUnwrapping
#    4956.5 ms  ✓ ChainRulesCore
#    7918.9 ms  ✓ FixedPointNumbers
#    4610.5 ms  ✓ UnicodeFun
#    2467.3 ms  ✓ Graphite2_jll
#    4961.9 ms  ✓ TableOperations
#    1802.7 ms  ✓ EpollShim_jll
#    1890.8 ms  ✓ Libmount_jll
#    2178.9 ms  ✓ LLVMOpenMP_jll
#    2273.5 ms  ✓ Rmath_jll
#    1931.0 ms  ✓ Xorg_libICE_jll
#    1913.4 ms  ✓ Xorg_libXau_jll
#    2453.1 ms  ✓ libpng_jll
#    2382.7 ms  ✓ libfdk_aac_jll
#    2448.8 ms  ✓ LAME_jll
#    2349.5 ms  ✓ LERC_jll
#    2334.6 ms  ✓ fzf_jll
#    2638.7 ms  ✓ JpegTurbo_jll
#    2727.9 ms  ✓ XZ_jll
#    1898.1 ms  ✓ Xorg_libXdmcp_jll
#    1922.7 ms  ✓ mtdev_jll
#    2318.9 ms  ✓ Ogg_jll
#    2219.4 ms  ✓ x265_jll
#    2148.9 ms  ✓ x264_jll
#    2482.3 ms  ✓ Arpack_jll
#    2378.4 ms  ✓ Zstd_jll
#    2500.1 ms  ✓ MbedTLS_jll
#    2251.0 ms  ✓ libaom_jll
#    1808.3 ms  ✓ Xorg_xtrans_jll
#    2284.3 ms  ✓ Expat_jll
#    2257.8 ms  ✓ LZO_jll
#    2244.9 ms  ✓ Opus_jll
#    1883.8 ms  ✓ libevdev_jll
#    1853.9 ms  ✓ eudev_jll
#    2191.4 ms  ✓ Libffi_jll
#    2361.1 ms  ✓ Libiconv_jll
#    2294.9 ms  ✓ FFTW_jll
#    1828.3 ms  ✓ Libuuid_jll
#    2087.1 ms  ✓ FriBidi_jll
#    2233.8 ms  ✓ FreeType2_jll
#    4020.9 ms  ✓ FilePathsBase → FilePathsBaseTestExt
#    4663.9 ms  ✓ RecipesBase
#    3787.2 ms  ✓ IntelOpenMP_jll
#    4098.7 ms  ✓ oneTBB_jll
#    3468.4 ms  ✓ HypergeometricFunctions
#    1293.1 ms  ✓ Showoff
#    2393.2 ms  ✓ Distances
#    1389.4 ms  ✓ FillArrays → FillArraysStatisticsExt
#    1206.4 ms  ✓ Ratios
#    4978.8 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#    1984.8 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    1435.9 ms  ✓ Adapt
#    1560.1 ms  ✓ AliasTables
#    1749.9 ms  ✓ RelocatableFolders
#    2741.9 ms  ✓ PDMats
#    2127.4 ms  ✓ AxisAlgorithms
#    1893.4 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    1571.5 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    6735.7 ms  ✓ OpenSSL
#    5165.7 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    2242.4 ms  ✓ Pixman_jll
#    6306.8 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    1898.0 ms  ✓ Xorg_libSM_jll
#    2580.8 ms  ✓ Rmath
#    4655.3 ms  ✓ ColorTypes
#    2175.9 ms  ✓ JLFzf
#    1760.1 ms  ✓ Xorg_libxcb_jll
#    2519.4 ms  ✓ Arpack
#    3249.2 ms  ✓ libvorbis_jll
#    3882.4 ms  ✓ Libtiff_jll
#    5992.2 ms  ✓ Ghostscript_jll
#   26570.1 ms  ✓ StaticArrays
#    2785.7 ms  ✓ Dbus_jll
#    2146.0 ms  ✓ libinput_jll
#    2213.1 ms  ✓ Wayland_jll
#    5044.9 ms  ✓ MbedTLS
#    3028.8 ms  ✓ GettextRuntime_jll
#    1545.2 ms  ✓ Distances → DistancesChainRulesCoreExt
#    3837.0 ms  ✓ Fontconfig_jll
#    2251.6 ms  ✓ Distances → DistancesSparseArraysExt
#    1438.0 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#    1350.3 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#    1803.4 ms  ✓ Adapt → AdaptSparseArraysExt
#    1887.4 ms  ✓ FillArrays → FillArraysPDMatsExt
#    1298.3 ms  ✓ ColorTypes → StyledStringsExt
#    4973.9 ms  ✓ StatsFuns
#    6500.2 ms  ✓ StatsBase
#    6166.8 ms  ✓ ColorVectorSpace
#    2002.6 ms  ✓ Xorg_xcb_util_jll
#    1842.3 ms  ✓ Xorg_libX11_jll
#    1812.5 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    1802.2 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    1603.8 ms  ✓ Adapt → AdaptStaticArraysExt
#    3162.0 ms  ✓ Glib_jll
#    9310.7 ms  ✓ Latexify
#   15928.0 ms  ✓ Colors
#    2562.2 ms  ✓ PDMats → StatsBaseExt
#    5844.3 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#    1664.9 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    1726.6 ms  ✓ Xorg_xcb_util_image_jll
#    1774.7 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1735.7 ms  ✓ Xorg_xcb_util_renderutil_jll
#    1681.9 ms  ✓ Xorg_xcb_util_wm_jll
#    1847.4 ms  ✓ Xorg_libXrender_jll
#    1891.8 ms  ✓ Xorg_libXext_jll
#    2044.5 ms  ✓ Xorg_libXfixes_jll
#    1946.0 ms  ✓ Xorg_libxkbfile_jll
#    2780.4 ms  ✓ Latexify → SparseArraysExt
#   33242.2 ms  ✓ MKL_jll
#    6331.0 ms  ✓ Interpolations
#    7774.7 ms  ✓ NearestNeighbors
#    2501.1 ms  ✓ Widgets
#    4526.1 ms  ✓ Latexify → DataFramesExt
#    1695.5 ms  ✓ Xorg_xcb_util_cursor_jll
#    1677.3 ms  ✓ Xorg_libXinerama_jll
#    1655.4 ms  ✓ Xorg_libXrandr_jll
#    1719.7 ms  ✓ Libglvnd_jll
#    1666.7 ms  ✓ Xorg_libXcursor_jll
#    3097.1 ms  ✓ Cairo_jll
#    1719.5 ms  ✓ Xorg_libXi_jll
#    1639.6 ms  ✓ Xorg_xkbcomp_jll
#   14158.5 ms  ✓ ColorSchemes
#    4997.8 ms  ✓ Clustering
#   14183.5 ms  ✓ Distributions
#    2010.5 ms  ✓ Xorg_xkeyboard_config_jll
#    2958.3 ms  ✓ HarfBuzz_jll
#    2950.5 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    3855.2 ms  ✓ Distributions → DistributionsTestExt
#    2318.0 ms  ✓ xkbcommon_jll
#    6448.5 ms  ✓ MultivariateStats
#    3860.2 ms  ✓ libass_jll
#    3461.2 ms  ✓ Vulkan_Loader_jll
#    5094.2 ms  ✓ Pango_jll
#   57152.0 ms  ✓ HTTP
#    9543.7 ms  ✓ FFMPEG_jll
#    4609.4 ms  ✓ libdecor_jll
#   10643.7 ms  ✓ Qt6Base_jll
#    2515.4 ms  ✓ FFMPEG
#    2837.1 ms  ✓ GLFW_jll
#   35199.4 ms  ✓ FFTW
#    3169.7 ms  ✓ Qt6ShaderTools_jll
#    4321.1 ms  ✓ GR_jll
#    6149.7 ms  ✓ KernelDensity
#   37135.0 ms  ✓ PlotUtils
#    9448.9 ms  ✓ Qt6Declarative_jll
#    1406.8 ms  ✓ Qt6Wayland_jll
#    7607.5 ms  ✓ PlotThemes
#   10991.2 ms  ✓ RecipesPipeline
#   12045.6 ms  ✓ GR
#  112895.4 ms  ✓ Plots
#    5523.0 ms  ✓ Plots → IJuliaExt
#   11451.9 ms  ✓ StatsPlots
#   176 dependencies successfully precompiled in 297 seconds. 93 already precompiled.
#   1 dependency had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: IntelOpenMP
# │   Downloading artifact: oneTBB
# └

# %% [markdown]
# Now, let’s load these packages:

# %%
using Plots, StatsPlots

# %% [markdown]
# ------------------------------------------------------------------------
#
# # Section 1 - Creating Basic Plots
#
# The Plots.jl package simplifies the process of creating a wide array of
# plots, from simple line plots to complex 3D visualizations. Let’s start
# with the simplest type of plot: a line plot. We’ll create some example
# data and then plot it.

# %%
# Create some example data
x = 1:10      # This creates a range of numbers from 1 to 10
y = rand(10)  # This creates 10 random numbers between 0 and 1

# Create a basic line plot
line_plot = plot(
    x, y,
    title="My First Line Plot",
    xlabel="X-axis Label",
    ylabel="Y-axis Label",
    legend=false
)

# Display the plot
display(line_plot)

# %% [markdown]
# Let’s break down what each part of this code does:
#
# -   `plot(x, y, ...)` creates the plot using our x and y data
# -   `title=...` sets the title of the plot
# -   `xlabel=...` and `ylabel=...` label the x and y axes
# -   `legend=false` turns off the legend (we’ll use this later)
#
# ## Exercise 1.1 - Create a Scatter Plot
#
# Now it’s your turn! Create a scatter plot using the `scatter()` function
# instead of `plot()`. Use a range from 1 to 20 for x, and generate 20
# random numbers for y.

# %%
# YOUR CODE BELOW
# Hint: Use x = 1:20 and y = rand(20)
x = 1:20
y = rand(20)

scatter_plot = plot(
    x, y,
    title = "My first scatter plot",
    xlabel = "X-axis label",
    ylabel = "Y-axis label",
    legend = false
)

display(scatter_plot)

# %%
# Test your answer
@assert @isdefined scatter_plot
println("Great job! You've created your first scatter plot.")
# Out:
# Great job! You've created your first scatter plot.

# %% [markdown]
# ------------------------------------------------------------------------
#
# # Section 2 - Customizing Plots
#
# One of the best things about Plots.jl is how easy it is to customize
# your plots. Let’s explore some options:

# %%
x = 1:10
y = rand(10)

custom_plot = plot(
    x, y,
    title="Customized Line Plot",
    xlabel="X-axis",
    ylabel="Y-axis",
    line=(:dash, 2),  # Dashed line with width 2
    color=:red,       # Red color
    marker=(:circle, 8)  # Circle markers of size 8
)

display(custom_plot)
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## Exercise 2.1 - Customize a Line Plot
#
# Now it’s your turn to get creative! Customize a line plot with your
# choice of colors, line styles, and markers. Save your masterpiece in the
# variable `custom_line_plot`.

# %%
# YOUR CODE BELOW
# Hint: Try different line styles (:dash, :dot), colors (:blue, :green), and markers (:star, :diamond)
x = 1:10
y = rand(10)

custom_line_plot = plot(
    x, y,
    title = "My first customized plot",
    xlabel = "X-axis",
    ylabel = "Y-axis",
    line = (:dot, 6),
    color = :green,
    marker = (:star, 10)
)

display(custom_line_plot)

# %%
# Test your answer
@assert @isdefined custom_line_plot
println("Excellent! You've created a custom line plot.")
# Out:
# Excellent! You've created a custom line plot.

# %% [markdown]
# > **Note**
# >
# > Feel free to experiment with different options. There’s no “right”
# > answer here – it’s all about what looks good to you!
#
# ------------------------------------------------------------------------
#
# # Section 3 - Adding Multiple Series to a Plot
#
# Now, let’s learn how to add multiple data series to a single plot:

# %%
x = 1:20
a = rand(20)
b = rand(20)

multi_plot = plot(
    x, a,
    title="Plot with Two Series",
    xlabel="X-axis",
    ylabel="Y-axis",
    label="Series A"
)
plot!(multi_plot,
    x, b,
    label="Series B"
)

display(multi_plot)
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# > **Note**
# >
# > The `plot!()` function (with an exclamation mark) adds to an existing
# > plot instead of creating a new one. In addition, we used the label
# > here to add a legend to the plot.
#
# ## Exercise 3.1 - Create a Multiple Series Plot
#
# NYour turn! Create a plot called `multi_series_plot` with three data
# series `y1`, `y2`, and `y3`. Make sure to give each series a different
# color and label.

# %%
# YOUR CODE BELOW
# Hint: Use plot() for the first series, then plot!() for the second and third
x = 1:10
y1 = rand(10)
y2 = rand(10)
y3 = rand(10)

multi_series_plot = plot(
    x, y1,
    title = "My first multi series plot experience",
    xlabel = "X-axis",
    ylabel = "Y-axis",
    label = "Series Y1",
)

# The two seperate plot!() functions for the multi plots
plot!(multi_series_plot,
x, y2,
label = "Series Y2"
)

plot!(multi_series_plot,
x, y3,
label = "Series Y3"
)

display(multi_series_plot)

# %%
# Test your answer
@assert @isdefined y1
@assert @isdefined y2
@assert @isdefined y3
@assert @isdefined multi_series_plot
println("Fantastic! You've created a plot with multiple series.")
# Out:
# Fantastic! You've created a plot with multiple series.

# %% [markdown]
# ------------------------------------------------------------------------
#
# # Section 3 - Saving Plots to Files
#
# Plots.jl supports saving your plots to various file formats including
# PNG, SVG, and PDF, enabling you to use your plots outside of Julia. The
# function to save plots is `savefig()`, the first argument is the plot
# itself and the second argument is the `path/filename` format as string.
# Replace `path` with the path, the `filename` with the actual name and
# `format` with the file format, e.g. `pdf`, `png`, … . For example, if
# you want to save your file as PDF, you would just name it
# `path/filename.pdf`. For example:
#
# ``` julia
# savefig(plot_name, "path/filename.png")
# ```
#
# This saves the plot as a PNG file.
#
# ## Exercise 3.1 - Save a Plot to a File
#
# Save your `multi_series_plot` as a PNG file named “saved_plot.png” in
# the “ExampleData” folder.

# %%
# YOUR CODE BELOW
# Don't forget to use the @__DIR__ macro to get the correct file path!
savefig(multi_series_plot, "$(@__DIR__)/ExampleData/saved_plot.png")
# Out:
# "c:\\Users\\Ozan Arif Yavuz\\OneDrive\\Masaüstü\\Applied Optimization\\ExampleData\\saved_plot.png"

# %%
# Test your answer
@assert isfile("$(@__DIR__)/ExampleData/saved_plot.png") "File does not exist yet."
println("Well done! You've saved your plot as an image file.")
# Out:
# Well done! You've saved your plot as an image file.

# %% [markdown]
# ------------------------------------------------------------------------
#
# # Section 4 - Advanced Plotting Techniques
#
# Let’s explore some other common plot types. While you don’t have to
# solve any task here, the code might come in handy later on during the
# course as recipe.
#
# ## Bar Plot

# %%
# Bar plot
x_categories = ["A", "B", "C", "D"]
y_values = [15, 23, 18, 30]
bar_plot = bar(
    x_categories,
    y_values,
    title="Bar Plot Example"
)
display(bar_plot)

# %% [markdown]
# ## Histogram

# %%
data = randn(1000)
hist_plot = histogram(
    data,
    bins=30,
    title="Histogram Example"
)
display(hist_plot)

# %% [markdown]
# ## Box Plot

# %%
# Box plot
group = repeat(1:4, inner=50)
y = randn(200) .+ group
box_plot = boxplot(
    group,
    y,
    title="Box Plot Example"
)
display(box_plot)

# %% [markdown]
# ------------------------------------------------------------------------
#
# # Conclusion
#
# Fantastic! You’ve completed the tutorial on basic plotting in Julia.
# You’ve learned how to create basic plots and customize and save them.
# Continue to the next file to learn more.
#
# # Solutions
#
# You will likely find solutions to most exercises online. However, I
# strongly encourage you to work on these exercises independently without
# searching explicitly for the exact answers to the exercises.
# Understanding someone else’s solution is very different from developing
# your own. Use the lecture notes and try to solve the exercises on your
# own. This approach will significantly enhance your learning and
# problem-solving skills.
#
# Remember, the goal is not just to complete the exercises, but to
# understand the concepts and improve your programming abilities. If you
# encounter difficulties, review the lecture materials, experiment with
# different approaches, and don’t hesitate to ask for clarification during
# class discussions.
